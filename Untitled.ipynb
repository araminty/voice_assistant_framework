# %%
import json

with open('clf_data.json') as file:
    data = json.load(file)

# %%
data.keys()

# %%
import pandas as pd
df = pd.DataFrame(columns=['utterance', 'intent'])

for k, j in data.items():
    df2 = pd.DataFrame(j, columns=['utterance'])
    df2['intent'] = k
    df = pd.concat([df, df2], ignore_index=True)
    
df.to_csv('utterances.csv')

# %%
df2 = pd.DataFrame(columns=['sentence', 'labels'])

for path in ['svp_engines/get_balance_svp_engine/data.json',\
'svp_engines/get_transactions_svp_engine/data.json',\
'svp_engines/money_svp_engine/data.json',\
'svp_engines/spending_advice_svp_engine/data.json',\
'svp_engines/spending_history_svp_engine/data.json']:
        with open(path) as file:
            data2 = json.load(file)['sentences']
            for sentence in data2:
                labels = ''
                for word in sentence['svpLabels']:
                    if word['label']!="O":
                        labels= f"{labels}[ {word['label']} : {word['word']} ]"
                
                df2 = pd.concat([df2, pd.DataFrame([[sentence['sentence'], labels]], columns=['sentence', 'labels'])])

# %%
list(zip(datasets, names))

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
from numpy import array, append

datasets = ['svp_engines/get_balance_svp_engine/data.json',\
'svp_engines/get_transactions_svp_engine/data.json',\
'svp_engines/money_svp_engine/data.json',\
'svp_engines/spending_advice_svp_engine/data.json',\
'svp_engines/spending_history_svp_engine/data.json']

names = ['balance', 'transactions', 'money', 'advice', 'history']


MAX_LENGTH = 25

slot_data = {}

for (dataset, name) in zip(datasets, names):
    X = []
    Y = []
    
    with open(dataset) as file:
        data=json.load(file)['sentences']
        for phrase in data:
            labels = phrase['svpLabels']+[{0.:0.}]*(max(0, MAX_LENGTH-len(phrase['svpLabels'])))
            try:
                words = [label['word'] for label in labels[:25]]
                labels = [label['label'] for label in labels[:25]]
                X.append(words)
                Y.append(labels)
            except:
                pass
        slot_data[name]={"X":X, "Y":Y}

# %%
padding = [ 0.0 ]*25

for (dataset, name) in zip(datasets, names):
    phrasing=pd.DataFrame(columns=list(range(25)))
    tokens=pd.DataFrame(columns=list(range(25)))
    with open(dataset) as file:
        data=json.load(file)['sentences']
        for phrase in data:
#             print(phrase)
            try:
                labels = [word['label'].replace('#', 'number') for word in phrase['svpLabels']]
                words = [word['word'] for word in phrase['svpLabels']]
                words = words[:25] + padding[len(words):]
                labels = labels[:25] + padding[len(labels):]
                phrasing.loc[phrasing.shape[0]]=words
                tokens.loc[tokens.shape[0]]=labels
            except:
                print(phrase)
                break
        print(phrasing.shape)
        phrasing.to_csv(name+'_words.csv', sep='|')
        tokens.to_csv(name+'_labels.csv', sep='|')
# Out:
# (2690, 25)
# (6182, 25)
# (0, 25)
# (2386, 25)
# (3746, 25)

# %%
slot_data.keys()

# %%
pd.DataFrame(slot_data['balance']['X'])

# %%
slot_data
df_slots = pd.DataFrame(columns=['tokens', 'labels', 'intent'])


for k, j in slot_data.items():
    df3 = pd.DataFrame()
    df3['tokens'] = j['X']
    df3['labels'] = j['Y']
    df3['intent'] = k
    df_slots = pd.concat([df_slots, df3], ignore_index=True)
    
df_slots.head()

# %%
with open('svp_engines/get_balance_svp_engine/data.json') as file:
    data2 = json.load(file)['sentences']

for p in data2[0]['svpLabels']:
    print(p.keys())

# %%
df2['labels'] = df2.labels.str.replace('\]\[', ',')

# %%
df2.tail()

# %%
df2['sentence'].str.split().apply(len).value_counts().sort_index()

# %%
import tensorflow as tf

# %%
train_dataset = train_dataset.shuffle(BUFFER_SIZE)
train_dataset = train_dataset.padded_batch(BATCH_SIZE, train_dataset.output_shapes)

test_dataset = test_dataset.padded_batch(BATCH_SIZE, test_dataset.output_shapes)

model = tf.keras.Sequential([
    tf.keras.layers.Embedding(encoder.vocab_size, 64),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model.compile(loss='binary_crossentropy',
              optimizer=tf.keras.optimizers.Adam(1e-4),
              metrics=['accuracy'])

# %%
# assign tag to word tokens from the following categories (IOB format):
# (I-PER, I-LOC, I-ORG, I-MISC, O)
# Ignore boundaries in this example, so every entity is of type "I-"")
#
# after 10 iterations
# class | precision,recall,fscore,support
# I-MISC | 0.71   0.33    0.45    258
# I-LOC | 0.86    0.62    0.72    260
# I-ORG | 0.69    0.56    0.62    362
# I-PER | 0.91    0.66    0.77    320
#
# after 50 iterations
# class | precision,recall,fscore,support
# I-MISC | 0.68	0.52	0.59	258
# I-LOC | 0.80	0.81	0.80	260
# I-ORG | 0.73	0.64	0.68	362
# I-PER | 0.88	0.94	0.91	320


import os
# dont use GPU
os.environ["CUDA_VISIBLE_DEVICES"]=""

import sys
import numpy as np
np.random.seed(31415)

# keras >= 2.0.3
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Bidirectional, LSTM, Activation, Dense, Dropout, TimeDistributed, Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, precision_recall_fscore_support, accuracy_score
import itertools

BASE_DIR = '.'
GLOVE_DIR = BASE_DIR + '/glove.6B/'
MAX_LEN = 64
USE_PRETRAINED_EMB = False
USE_BIDIRECTIONAL = True


#--------------------------------------------------------
# list of lists
X, Y = [], []
with open('wikigold.conll.txt', 'r', encoding='utf-8') as f:
    content = f.read()

# sentences are separated by \n\n
sentences = content.split("\n\n")[:-1]
for sentence in sentences:
    tokens = sentence.split("\n")

    x, y = [], []
    for token in tokens:
        tuple = token.split(" ")
        x.append(tuple[0])
        y.append(tuple[1])

    # ignore sentences with more than MAX_LEN words
    if (len(x) > MAX_LEN) or (len(x) <= 1):
        continue

    X.append(x)
    Y.append(y)

#--------------------------------------------------------

# take a list of values and hot-encode
# returns list of lists
def encode(arr, num_labels):
    ret = []
    for item in arr:
        a = np.zeros(num_labels, dtype=np.int32)
        a[item] = 1
        ret.append(a)
    return ret


# build vocabulary of words and entities
words = set(itertools.chain(*X))
entities = set(itertools.chain(*Y))

# %%
list(enumerate(entities))
# Out:
# [(0, 'I-PER'), (1, 'O'), (2, 'I-ORG'), (3, 'I-LOC'), (4, 'I-MISC')]

# %%
entity2idx
# Out:
# {'I-PER': 1, 'O': 2, 'I-ORG': 3, 'I-LOC': 4, 'I-MISC': 5}

# %%
# reserve index 0 for padding/masking
idx2word = dict((i+1,v) for i,v in enumerate(words))
word2idx = dict((v, i+1) for i,v in enumerate(words))

idx2entity = dict((i+1,v) for i,v in enumerate(entities))
entity2idx = dict((v, i+1) for i,v in enumerate(entities))

num_entities = len(entity2idx) + 1
num_words = len(word2idx) + 1

# %%
num_entities, num_words
# Out:
# (6, 8292)

# %%
print('num_words = {0}, num_entities = {1}'.format(num_words, num_entities))

# index encoder
X_enc = list(map(lambda x: [word2idx[wx] for wx in x], X))
Y_enc = list(map(lambda y: [entity2idx[wy] for wy in y], Y))


# one-hot encoder
Y_oh_enc = list(map(lambda y: encode(y, num_labels=num_entities), Y_enc))


# pad and truncate
X_all = pad_sequences(X_enc, MAX_LEN) # has shape (#samples, 64)
Y_all = pad_sequences(Y_oh_enc, MAX_LEN) # has shape (#samples, 64, 6)


# construct training and test sets
X_train, X_test, Y_train, Y_test = train_test_split(X_all, Y_all, test_size=10*32, train_size=40*32, random_state=42)
print ('Training and testing tensor shapes:', X_train.shape, X_test.shape, Y_train.shape, Y_test.shape)


embedding_size = 100
num_cells = 64
batch_size = 32
num_epochs = 10

# construct the NN model
model = Sequential()

# embed into vector space of dimension embedding_size
# input value 0 is a special "padding" value that should be masked out

# initialize with pretrained wordvectors
if USE_PRETRAINED_EMB:
    print('Indexing word vectors.')
    embeddings_index = {}
    try:
        f = open(os.path.join(GLOVE_DIR, 'glove.6B.100d.txt'))
    except:
        print("Cannot open Glove file. Please download from http://nlp.stanford.edu/data/glove.6B.zip")
        sys.exit(0)
    for line in f:
        values = line.split()
        word = values[0]
        coefs = np.asarray(values[1:], dtype='float32')
        embeddings_index[word] = coefs
    f.close()

    embedding_matrix = np.zeros((num_words, embedding_size))
    for word, i in word2idx.items():
        # lowercase the words
        embedding_vector = embeddings_index.get(word.lower())
        if embedding_vector is not None:
            # words not found in embedding index will be zero
            embedding_matrix[i] = embedding_vector

    embedding_layer = Embedding(len(word2idx) + 1,
                                embedding_size,
                                weights=[embedding_matrix],
                                input_length=MAX_LEN,
                                trainable=True, mask_zero = True)
    model.add(embedding_layer)
else:
    # initialize with random vectors
    model.add(Embedding(len(word2idx)+1, embedding_size, input_length=MAX_LEN, mask_zero=True))

# add LSTM layer; return all sequences for the output
if USE_BIDIRECTIONAL:
    model.add(Bidirectional(LSTM(num_cells, return_sequences=True)))
else:
    model.add(LSTM(num_cells, return_sequences=True))

# some regularization
model.add(Dropout(0.2))

# applies a same Dense (fully-connected) operation at every timestep
model.add(TimeDistributed(Dense(len(entity2idx)+1)))
model.add(Activation('softmax'))

# use multi-class loss function and adaptive gradient descent optimizer
model.compile(optimizer='adam', loss='categorical_crossentropy')
print (model.summary())

# train the model
model.fit(X_train, Y_train, batch_size=batch_size, nb_epoch=num_epochs, validation_data=(X_test, Y_test))

# test the model
Y_test_pred = model.predict_classes(X_test)

# to generate confusion matrix first remove the zero masked inputs and outputs
def clean(y_pred, y_gnd):
    coords = [np.where(y > 0)[0][0] for y in y_gnd]
    y_pred_unpad = [y[coord:] for coord, y in zip(coords, y_pred)]
    y_gnd_unpad = [y[coord:] for coord, y in zip(coords, y_gnd)]
    return y_pred_unpad, y_gnd_unpad

y_p_u, y_g_u = clean(Y_test_pred, Y_test.argmax(2))

#flatten to single array with class labels
y_p_u = list(itertools.chain(*y_p_u)) # predicted
y_g_u = list(itertools.chain(*y_g_u)) # ground

print ('\nTesting accuracy (all entities):', accuracy_score(y_g_u, y_p_u))
print ('\nconfusion matrix:')
print (confusion_matrix(y_g_u, y_p_u))
precision, recall, fscore, support  = precision_recall_fscore_support(y_g_u, y_p_u)
print('class | precision,recall,fscore,support')
for tag, i in entity2idx.items():
    if tag == 'O':
        continue
    print('{0} | {1:1.2f}\t{2:1.2f}\t{3:1.2f}\t{4}'.format(tag, precision[i-1], recall[i-1], fscore[i-1], support[i-1]))


# # visualize output for some random inputs
# for _ in range(5):
#     vis_idx = np.random.randint(1600)
#     Y_vis_pred = model.predict_classes(X_all[vis_idx].reshape(1,MAX_LEN))
#     y_vis_u, _ = clean(Y_vis_pred, [Y_all[vis_idx].argmax(1)])
#     y_vis_u_l = [idx2entity[val] for val in y_vis_u[0]]
#     print("\nInput sentence: {}".format(' '.join(X[vis_idx])))
#     print("Predict entities: {}".format(' '.join(y_vis_u_l)))
#     print("Correct entities: {}".format(' '.join(Y[vis_idx])))
# Out:
# num_words = 8292, num_entities = 6
# Training and testing tensor shapes: (1280, 64) (320, 64) (1280, 64, 6) (320, 64, 6)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 64, 100)           829200
# _________________________________________________________________
# bidirectional (Bidirectional (None, 64, 128)           84480
# _________________________________________________________________
# dropout (Dropout)            (None, 64, 128)           0
# _________________________________________________________________
# time_distributed (TimeDistri (None, 64, 6)             774
# _________________________________________________________________
# activation (Activation)      (None, 64, 6)             0
# =================================================================
# Total params: 914,454
# Trainable params: 914,454
# Non-trainable params: 0
# _________________________________________________________________
# None
# WARNING:tensorflow:The `nb_epoch` argument in `fit` has been renamed `epochs`.
# Train on 1280 samples, validate on 320 samples
# Epoch 1/10
# 1280/1280 [==============================] - 17s 14ms/sample - loss: 0.3854 - val_loss: 0.2555
# Epoch 2/10
# 1280/1280 [==============================] - 4s 3ms/sample - loss: 0.2293 - val_loss: 0.2138
# Epoch 3/10
# 1280/1280 [==============================] - 4s 3ms/sample - loss: 0.1809 - val_loss: 0.1688
# Epoch 4/10
# 1280/1280 [==============================] - 4s 3ms/sample - loss: 0.1325 - val_loss: 0.1408
# Epoch 5/10
# 1280/1280 [==============================] - 4s 3ms/sample - loss: 0.1028 - val_loss: 0.1333
# Epoch 6/10
# 1280/1280 [==============================] - 4s 3ms/sample - loss: 0.0887 - val_loss: 0.1291
# Epoch 7/10
# 1280/1280 [==============================] - 4s 3ms/sample - loss: 0.0751 - val_loss: 0.1284
# Epoch 8/10
# 1280/1280 [==============================] - 4s 3ms/sample - loss: 0.0552 - val_loss: 0.1219
# Epoch 9/10
# 1280/1280 [==============================] - 4s 3ms/sample - loss: 0.0366 - val_loss: 0.1133
# Epoch 10/10
# 1280/1280 [==============================] - 4s 3ms/sample - loss: 0.0233 - val_loss: 0.1085
#
# Testing accuracy (all entities): 0.9203860072376358
#
# confusion matrix:
# [[ 200   96   20    1    3]
#  [   8 6187   35    6   25]
#  [  11  130  200   13    8]
#  [   7   53   20  167   13]
#  [   2  125   15    3  113]]
# class | precision,recall,fscore,support
# I-PER | 0.88	0.62	0.73	320
# I-ORG | 0.69	0.55	0.61	362
# I-LOC | 0.88	0.64	0.74	260
# I-MISC | 0.70	0.44	0.54	258

# %%
model.layers[0].output_dim, model.layers[0].input_dim
# Out:
# (100, 8292)

# %%
X_train[0].shape
# Out:
# (64,)

# %%
for l in model.layers:
    print(l)
# Out:
# <tensorflow.python.keras.layers.embeddings.Embedding object at 0x000001FE39F86A48>
# <tensorflow.python.keras.layers.wrappers.Bidirectional object at 0x000001FE3B5C3A08>
# <tensorflow.python.keras.layers.core.Dropout object at 0x000001FE3B5B2F88>
# <tensorflow.python.keras.layers.wrappers.TimeDistributed object at 0x000001FE3E8CFC88>
# <tensorflow.python.keras.layers.core.Activation object at 0x000001FE3B5E2BC8>

# %%
model.layers[1].

# %%
word2idx
# Out:
# {'48': 1,
#  'artist': 2,
#  'stops': 3,
#  'Parish': 4,
#  'pulling': 5,
#  'Anti-Jacksonian': 6,
#  'invasion': 7,
#  'carrying': 8,
#  'verdicts': 9,
#  'András': 10,
#  '1974': 11,
#  'devise': 12,
#  'Mendelssohn': 13,
#  'Scouting': 14,
#  'Coleman': 15,
#  'Houston': 16,
#  'Roberta': 17,
#  'preliminary': 18,
#  'Bambos': 19,
#  'fills': 20,
#  'resident': 21,
#  'Indie': 22,
#  'meandering': 23,
#  'realists': 24,
#  'Also': 25,
#  'USSR': 26,
#  'room': 27,
#  'Twin': 28,
#  'college': 29,
#  'colonial': 30,
#  'stringer': 31,
#  'Landes': 32,
#  'Goan': 33,
#  'phrase': 34,
#  'Greece': 35,
#  'Pro': 36,
#  'Bobby': 37,
#  'Germans': 38,
#  '16,000': 39,
#  'OASA': 40,
#  'ISAP': 41,
#  'attract': 42,
#  'visited': 43,
#  'Oahu': 44,
#  'goaltender': 45,
#  'der': 46,
#  'a': 47,
#  'naval': 48,
#  'Orchestra': 49,
#  'exploded': 50,
#  'bandmates': 51,
#  'drafted': 52,
#  'USA': 53,
#  'planted': 54,
#  'won': 55,
#  'depots': 56,
#  'guard': 57,
#  'Mostar': 58,
#  'Mistress': 59,
#  'Italian-American': 60,
#  'heard': 61,
#  'sandbox': 62,
#  'Poolesville': 63,
#  'BP': 64,
#  '50': 65,
#  'Salling': 66,
#  'J': 67,
#  'Frazier': 68,
#  'muscles': 69,
#  'spelt': 70,
#  'Sankranthi': 71,
#  'Bontnewydd': 72,
#  'Tampa': 73,
#  'faculty': 74,
#  'banjo-guitars': 75,
#  'fought': 76,
#  'cooperation': 77,
#  'sleeve': 78,
#  'project': 79,
#  'Copeland': 80,
#  'Mongolia': 81,
#  'Zealand': 82,
#  'polytechnic': 83,
#  'seven': 84,
#  'launching': 85,
#  '1988': 86,
#  'Civic': 87,
#  'father': 88,
#  'twists': 89,
#  'Buddhist': 90,
#  'testified': 91,
#  'Szomorú': 92,
#  'Origins': 93,
#  'nail': 94,
#  'crafting': 95,
#  'refuse': 96,
#  'Information': 97,
#  'tenth': 98,
#  'Jacksonville': 99,
#  'preserve': 100,
#  'Version': 101,
#  'Sacramento': 102,
#  'post-Ceauşescu': 103,
#  'Vasárnap': 104,
#  'features': 105,
#  'bodybuilding': 106,
#  'Marcus': 107,
#  'notable': 108,
#  'Civil': 109,
#  "J'ai": 110,
#  'Armistice': 111,
#  'designated': 112,
#  'Timberlands': 113,
#  'Orleans': 114,
#  'contractions': 115,
#  'explanation': 116,
#  'Resistance': 117,
#  'soldiers': 118,
#  'brother': 119,
#  'Many': 120,
#  'tirailleurs': 121,
#  'Tuesdays': 122,
#  'Gives': 123,
#  'newly': 124,
#  'Luigi': 125,
#  'Gascony': 126,
#  'puny': 127,
#  'north': 128,
#  'Sayler': 129,
#  'county': 130,
#  'turn': 131,
#  'Olympics': 132,
#  'probable': 133,
#  'Salem': 134,
#  'Newcomer': 135,
#  'Vendorado': 136,
#  '16-year-old': 137,
#  'DNA': 138,
#  'loans': 139,
#  'stop': 140,
#  'ILPAP': 141,
#  'Junction': 142,
#  'kick-starting': 143,
#  'Buchanan': 144,
#  'conditions': 145,
#  'men': 146,
#  'citizens': 147,
#  'board': 148,
#  'Baltimore': 149,
#  'aim': 150,
#  'Christi': 151,
#  'their': 152,
#  'Loft': 153,
#  'lush': 154,
#  'Philippines': 155,
#  'Hawker': 156,
#  'decideed': 157,
#  'making': 158,
#  '1-2': 159,
#  'Flanders': 160,
#  'undisturbed': 161,
#  'pillboxes': 162,
#  'Frank': 163,
#  'shoppers': 164,
#  'Glastonbury': 165,
#  'Saco': 166,
#  'sophomores': 167,
#  'course': 168,
#  'implicate': 169,
#  'kindergartens': 170,
#  'NYC': 171,
#  '1937': 172,
#  'Holdsworth': 173,
#  '1960s': 174,
#  'inscriptions': 175,
#  'citizenship': 176,
#  'Australia': 177,
#  'Skating': 178,
#  'vacated': 179,
#  'gather': 180,
#  'commune': 181,
#  'allotted': 182,
#  'French': 183,
#  'Rob': 184,
#  'CSHL': 185,
#  'referring': 186,
#  'Surabaya': 187,
#  'believe': 188,
#  '2.0': 189,
#  'Angelo': 190,
#  'destruction': 191,
#  'reading': 192,
#  'firm': 193,
#  'ranged': 194,
#  'transferred': 195,
#  'Engineer': 196,
#  'war': 197,
#  'Aufklarung': 198,
#  'revolutionary': 199,
#  'Rice': 200,
#  'box': 201,
#  'dissertation': 202,
#  'tragic': 203,
#  'turns': 204,
#  'Brazil': 205,
#  'relocation': 206,
#  'sings': 207,
#  'standings': 208,
#  'Brazilian': 209,
#  'just': 210,
#  'spelled': 211,
#  'Carvolth': 212,
#  'wrecked': 213,
#  'Winkel': 214,
#  'Sydney': 215,
#  'Results': 216,
#  'immobilise': 217,
#  'reach': 218,
#  'Tyne': 219,
#  'affair': 220,
#  'two': 221,
#  'pencils': 222,
#  'bridges': 223,
#  'homebuilder': 224,
#  'republicanism': 225,
#  'specialist': 226,
#  'fluent': 227,
#  'Manwatch': 228,
#  'Gutawa': 229,
#  'give': 230,
#  'offers': 231,
#  'dozen': 232,
#  'pauperes': 233,
#  '30': 234,
#  '?': 235,
#  'Peninsula': 236,
#  'Park': 237,
#  'sound': 238,
#  'fury': 239,
#  'injuring': 240,
#  '2007': 241,
#  'Lady': 242,
#  'author': 243,
#  'All-SWC': 244,
#  'BED': 245,
#  'Professor': 246,
#  'rooted': 247,
#  'control': 248,
#  'Market': 249,
#  'Adan': 250,
#  '$35,000': 251,
#  'milking': 252,
#  'amongst': 253,
#  'Next': 254,
#  'Air': 255,
#  'tenor': 256,
#  'Li': 257,
#  'games': 258,
#  'Spanish-Ilocano': 259,
#  'presenting': 260,
#  'Turpentine': 261,
#  'condition': 262,
#  'traveled': 263,
#  'separate': 264,
#  'midfielder': 265,
#  'trying': 266,
#  'savings': 267,
#  'Squirrell': 268,
#  'AM': 269,
#  'Contest': 270,
#  'Iowa': 271,
#  'Evolution': 272,
#  'Bowl': 273,
#  '1960': 274,
#  '34': 275,
#  'due': 276,
#  'technique': 277,
#  'WTCC': 278,
#  'key': 279,
#  'wood': 280,
#  'behalf': 281,
#  'maximize': 282,
#  'cortex': 283,
#  'severely': 284,
#  'Lucy': 285,
#  'casting': 286,
#  'Adeon': 287,
#  'AMEL': 288,
#  'Independence': 289,
#  'Paulo': 290,
#  'UPI': 291,
#  'Science': 292,
#  'association': 293,
#  'BayCon': 294,
#  'Surfwear': 295,
#  'Legacy': 296,
#  'off': 297,
#  'Mattias': 298,
#  'NAACP': 299,
#  'Super': 300,
#  'pro-life': 301,
#  'deer': 302,
#  'renumbered': 303,
#  'followed': 304,
#  'Representative': 305,
#  'Toshiba-EMI': 306,
#  'moments': 307,
#  'come': 308,
#  'millions': 309,
#  'extensively': 310,
#  'Pump': 311,
#  'intervention': 312,
#  'Buffalo': 313,
#  '-1985': 314,
#  'A.': 315,
#  'announced': 316,
#  'Digilogue': 317,
#  'carbonate': 318,
#  'facility': 319,
#  'Marlboro': 320,
#  'bearing': 321,
#  'Camp': 322,
#  'Shree': 323,
#  'Newark': 324,
#  'anniversary': 325,
#  'interstate': 326,
#  'India': 327,
#  'Miličević': 328,
#  'underwent': 329,
#  'Lee': 330,
#  'Nassau': 331,
#  'crops': 332,
#  'tributes': 333,
#  'Menestrallus': 334,
#  'poems': 335,
#  'ca': 336,
#  'belt': 337,
#  '15%': 338,
#  'Laser': 339,
#  'controller': 340,
#  'Vision': 341,
#  'Was': 342,
#  'attitude': 343,
#  'subjects': 344,
#  'Nâdiy': 345,
#  'Antipodes': 346,
#  'Activities': 347,
#  'Fiji': 348,
#  'journal': 349,
#  'oldest': 350,
#  'tours': 351,
#  '1980': 352,
#  'Oh': 353,
#  'Fremantle': 354,
#  'Saturnino': 355,
#  'Cuba': 356,
#  'Vertical': 357,
#  '1830': 358,
#  'street': 359,
#  'server': 360,
#  'destiny': 361,
#  '1837-1927': 362,
#  'Place': 363,
#  'schools': 364,
#  'How': 365,
#  'upcoming': 366,
#  'defence': 367,
#  'Lieutenant': 368,
#  'Nicola': 369,
#  'Mel': 370,
#  'approachable': 371,
#  'outrage': 372,
#  'filled': 373,
#  'life-threatening': 374,
#  'Travel': 375,
#  'Sudan': 376,
#  'Esteban': 377,
#  'future': 378,
#  '2006/07': 379,
#  'Maratha': 380,
#  'hillock': 381,
#  'Safety': 382,
#  'tournament': 383,
#  '2,700,000': 384,
#  'Twenty-fourth': 385,
#  'pass': 386,
#  'research': 387,
#  'commentary': 388,
#  'Irene': 389,
#  'gaily': 390,
#  'Darrell': 391,
#  'Esther': 392,
#  'MVP': 393,
#  'rebellion': 394,
#  'natives': 395,
#  'enginehouse': 396,
#  'OSC-DIS': 397,
#  'Raven': 398,
#  'real': 399,
#  'rookie': 400,
#  'name': 401,
#  'structure': 402,
#  'Christianos': 403,
#  'occupations': 404,
#  'Athens': 405,
#  'Columbia': 406,
#  'District': 407,
#  'Vancouver': 408,
#  'neck': 409,
#  'period': 410,
#  'Java': 411,
#  'Canadian': 412,
#  'Modeling': 413,
#  'traded': 414,
#  'Bains': 415,
#  'responded': 416,
#  'Mad': 417,
#  'Second': 418,
#  'obvious': 419,
#  'subdue': 420,
#  'reformed': 421,
#  'get': 422,
#  'Space': 423,
#  'polemicist': 424,
#  'headquarters': 425,
#  'feud': 426,
#  'Organization': 427,
#  '98th': 428,
#  'Cambridge': 429,
#  'affairs': 430,
#  'briefly': 431,
#  "Miller's": 432,
#  'Acting': 433,
#  'Bennett': 434,
#  'detail': 435,
#  'altogether': 436,
#  'owns': 437,
#  'Sentinel': 438,
#  'Bov': 439,
#  'Labor': 440,
#  'dirty': 441,
#  'KGB': 442,
#  'damage': 443,
#  'traveling': 444,
#  'Brandhorst': 445,
#  'damaged': 446,
#  'determined': 447,
#  'present': 448,
#  'Newell': 449,
#  '7-inning': 450,
#  'XVI': 451,
#  'jacks': 452,
#  '17': 453,
#  'learning': 454,
#  'Wachter': 455,
#  'scoreless': 456,
#  'Swedish': 457,
#  'choose': 458,
#  'Realists': 459,
#  'popularly': 460,
#  '45': 461,
#  'Graeme': 462,
#  'named': 463,
#  'M.': 464,
#  'Holmes': 465,
#  'Problem': 466,
#  'Harry': 467,
#  'drop': 468,
#  '7.2': 469,
#  'collegiate': 470,
#  'laureate': 471,
#  'commitments': 472,
#  'Rex': 473,
#  'little': 474,
#  'directed': 475,
#  'Universe': 476,
#  'Divizia': 477,
#  '200000': 478,
#  'masters': 479,
#  'Scribner': 480,
#  '5:40': 481,
#  'participants': 482,
#  'programs': 483,
#  'Studies': 484,
#  'succeeded': 485,
#  'dominance': 486,
#  'north-west': 487,
#  'Garrigan': 488,
#  'fifteen': 489,
#  'cartridges': 490,
#  'four-year': 491,
#  'ruthlessly': 492,
#  'Baggage': 493,
#  'Cosham': 494,
#  'plans': 495,
#  'accepting': 496,
#  'Riding': 497,
#  'Fortification': 498,
#  'firmly': 499,
#  'philosopher': 500,
#  'Brixton': 501,
#  'Rahel': 502,
#  'quitting': 503,
#  'local': 504,
#  'László': 505,
#  'Brensbach': 506,
#  'merged': 507,
#  'tall': 508,
#  'media-created': 509,
#  '38': 510,
#  'church': 511,
#  'vice': 512,
#  'Adelson': 513,
#  'Phillip': 514,
#  'resides': 515,
#  'And': 516,
#  'analogue': 517,
#  'area': 518,
#  'Alfred': 519,
#  'Deser': 520,
#  'helps': 521,
#  'families': 522,
#  '1969': 523,
#  'pick': 524,
#  'listening': 525,
#  '300': 526,
#  'seemed': 527,
#  'Department': 528,
#  'Pedr': 529,
#  'channel': 530,
#  'bankruptcy': 531,
#  'Vijaynagar': 532,
#  'solo': 533,
#  'Patrol': 534,
#  'driver': 535,
#  'Pezuela': 536,
#  'Telemundo': 537,
#  'siren': 538,
#  'Tomo': 539,
#  'Šibenik-Knin': 540,
#  'concern': 541,
#  'assistance': 542,
#  'power': 543,
#  'performance': 544,
#  'are': 545,
#  'colorfully': 546,
#  'mid-range': 547,
#  'Kuala': 548,
#  'Moderni': 549,
#  'youngest': 550,
#  'gain': 551,
#  'Seven': 552,
#  'commonly': 553,
#  'vein': 554,
#  'Stoloff': 555,
#  '883Jia': 556,
#  'contenders': 557,
#  'brand': 558,
#  'pulled': 559,
#  'Intelligence': 560,
#  'reshaped': 561,
#  'hotels': 562,
#  'numerous': 563,
#  'band': 564,
#  'recruit': 565,
#  'wins': 566,
#  'X86-based': 567,
#  'Adenes': 568,
#  'elegant': 569,
#  'among': 570,
#  'Osc-Dis': 571,
#  'hands': 572,
#  'starter': 573,
#  'Markets': 574,
#  'Speaker': 575,
#  'competition': 576,
#  'sanctity': 577,
#  'Tram': 578,
#  'anti-aircraft': 579,
#  'Challenge': 580,
#  'led': 581,
#  'presence': 582,
#  'organs': 583,
#  'Colclough': 584,
#  'guru': 585,
#  'double': 586,
#  'Record': 587,
#  'MySpace': 588,
#  'Have': 589,
#  'Mount': 590,
#  'retreat': 591,
#  '1,000,000': 592,
#  'below': 593,
#  'count': 594,
#  'signifies': 595,
#  'Cascade': 596,
#  'silence': 597,
#  'Pie': 598,
#  'Faludi': 599,
#  'BIRT': 600,
#  'between': 601,
#  '1847': 602,
#  'G.': 603,
#  'maintained': 604,
#  'Italian': 605,
#  'Daniels': 606,
#  'metal': 607,
#  'showed': 608,
#  'RPO': 609,
#  'links': 610,
#  'modified': 611,
#  'backup': 612,
#  'Bobick': 613,
#  'starring': 614,
#  'breaks': 615,
#  'Per': 616,
#  'Hendrix': 617,
#  'since': 618,
#  'Influence': 619,
#  'wooden': 620,
#  'daily': 621,
#  'Orders': 622,
#  'Attiko': 623,
#  'Stewart': 624,
#  'Ribandar': 625,
#  'environment': 626,
#  'rated': 627,
#  'fact': 628,
#  'spring': 629,
#  'flash': 630,
#  'Randall': 631,
#  'environmentally': 632,
#  'noon': 633,
#  'AA': 634,
#  'Barbara': 635,
#  'administered': 636,
#  'yrs': 637,
#  'Le': 638,
#  'surreal': 639,
#  'players': 640,
#  'Serbian': 641,
#  'ranks': 642,
#  'stock': 643,
#  'Tilst': 644,
#  'Established': 645,
#  'Caernarfon': 646,
#  'Laboratory': 647,
#  'also': 648,
#  'its': 649,
#  'Scientific': 650,
#  'far': 651,
#  'article': 652,
#  'Image': 653,
#  'Minnich': 654,
#  'considered': 655,
#  'beautiful': 656,
#  'interface': 657,
#  'partition': 658,
#  'Records': 659,
#  'excursionists': 660,
#  'Prize': 661,
#  'Corporations': 662,
#  'picture': 663,
#  'Pty': 664,
#  'Updates': 665,
#  'MAAA': 666,
#  'Champdor': 667,
#  'fun': 668,
#  'self-contained': 669,
#  'exclusively': 670,
#  'Brodian': 671,
#  'reference': 672,
#  'fares': 673,
#  'Sitamma': 674,
#  'agent': 675,
#  '93d': 676,
#  'telegraphed': 677,
#  'Beauty': 678,
#  'Shadow': 679,
#  'Championships': 680,
#  'parallel': 681,
#  'flank': 682,
#  'leave': 683,
#  'Poet': 684,
#  'medal': 685,
#  'recurred': 686,
#  ':': 687,
#  'tower': 688,
#  'Quantitative': 689,
#  'physically': 690,
#  'muscular': 691,
#  'portuguese': 692,
#  'operation': 693,
#  'humiliating': 694,
#  'preoccupied': 695,
#  '1843': 696,
#  'residents': 697,
#  'chaired': 698,
#  'discovered': 699,
#  'debut': 700,
#  '16.4': 701,
#  'Toronto': 702,
#  'Minoru': 703,
#  'Billiges': 704,
#  'Count': 705,
#  'Written': 706,
#  'trumpeter': 707,
#  '29': 708,
#  'Bouncing': 709,
#  'Liberties': 710,
#  '1762': 711,
#  'Diefenthal': 712,
#  'crossing': 713,
#  'Riperton': 714,
#  'enter': 715,
#  'stationery': 716,
#  'Nakhonphink': 717,
#  'Urbana-Champaign': 718,
#  'too': 719,
#  'Carlo': 720,
#  'depths': 721,
#  'threat': 722,
#  '1993': 723,
#  'Enrollment': 724,
#  'Linkin': 725,
#  'decided': 726,
#  'hunters': 727,
#  'transition': 728,
#  'Complex': 729,
#  'Frankfurt': 730,
#  'Player': 731,
#  'etc.': 732,
#  'ride': 733,
#  'owners': 734,
#  'Capelli': 735,
#  'industrial': 736,
#  'fate': 737,
#  'earliest': 738,
#  'America': 739,
#  'did': 740,
#  'footage': 741,
#  'buffalo': 742,
#  'AGS': 743,
#  'Oakland': 744,
#  'eligible': 745,
#  'Bunzel': 746,
#  'serious': 747,
#  '1895': 748,
#  'Ask.com': 749,
#  'Lubbock': 750,
#  'Metrobus': 751,
#  'fulfill': 752,
#  'hoped': 753,
#  'By': 754,
#  'Pavilion': 755,
#  'skulls': 756,
#  'programme': 757,
#  '1819': 758,
#  'children': 759,
#  'inexplicable': 760,
#  'constructed': 761,
#  'weapon': 762,
#  'Falls': 763,
#  'note': 764,
#  'Wiscasset': 765,
#  '144': 766,
#  'Philip': 767,
#  'architect': 768,
#  'Auton': 769,
#  'part-time': 770,
#  'Eagles': 771,
#  'boiling': 772,
#  'Elders': 773,
#  'cool': 774,
#  'Mesa': 775,
#  'National': 776,
#  'McGill': 777,
#  'summer': 778,
#  'hit': 779,
#  'Maxfield': 780,
#  'zoviet*france': 781,
#  'Moses': 782,
#  'replaced': 783,
#  'Gostkócity': 784,
#  'functionaries': 785,
#  'Dark': 786,
#  'element': 787,
#  'avoid': 788,
#  'legislative': 789,
#  'child': 790,
#  'principles': 791,
#  '1839': 792,
#  'prastut': 793,
#  'devices': 794,
#  'rain': 795,
#  'collapsible': 796,
#  'Experimental': 797,
#  'sensitivity': 798,
#  'Schelling': 799,
#  'shut': 800,
#  'ka': 801,
#  'Vaz': 802,
#  'battery': 803,
#  'switch': 804,
#  'Sheridan': 805,
#  'Joseph': 806,
#  'experiments': 807,
#  'feet': 808,
#  'things': 809,
#  'probability': 810,
#  'Bruins': 811,
#  'totaling': 812,
#  'York': 813,
#  'Houser': 814,
#  'Leto': 815,
#  'regarded': 816,
#  'camp': 817,
#  'trial': 818,
#  '/': 819,
#  'Former': 820,
#  'Widner': 821,
#  'names': 822,
#  'Iceland': 823,
#  'furthest': 824,
#  'Schlegel': 825,
#  "'": 826,
#  'invade': 827,
#  'Outback': 828,
#  'gathered': 829,
#  'villain': 830,
#  'promote': 831,
#  'jackpot': 832,
#  'month-long': 833,
#  'packed': 834,
#  'Shore': 835,
#  'Baby': 836,
#  'villas': 837,
#  'directing': 838,
#  'Discovery': 839,
#  '10:45': 840,
#  'discerned': 841,
#  'Gonzalo': 842,
#  'rematch': 843,
#  'model': 844,
#  'Alexandria': 845,
#  'Theatre': 846,
#  'Brain': 847,
#  'Weippert': 848,
#  'government': 849,
#  '1957': 850,
#  'immediately': 851,
#  'distribution': 852,
#  '1973': 853,
#  'nutrition': 854,
#  'Bresh': 855,
#  'inch': 856,
#  'science': 857,
#  '215': 858,
#  'Farmington': 859,
#  'promotion': 860,
#  'Upon': 861,
#  'technology': 862,
#  'Hopkins': 863,
#  'Shark': 864,
#  'failings': 865,
#  'W.': 866,
#  'ads': 867,
#  'Gustav': 868,
#  'Bridgton': 869,
#  'remembered': 870,
#  'Fighting': 871,
#  'top-10': 872,
#  'outcome': 873,
#  'branches': 874,
#  '£500': 875,
#  'displays': 876,
#  'talents': 877,
#  '$175': 878,
#  'Varela': 879,
#  'Nap': 880,
#  'player': 881,
#  'Baranja': 882,
#  'spot-in': 883,
#  'Defense': 884,
#  'Ax2': 885,
#  'untimely': 886,
#  'serial': 887,
#  'store': 888,
#  'nineties': 889,
#  'Rich': 890,
#  'policy': 891,
#  'omnibuses': 892,
#  'Prior': 893,
#  'classical': 894,
#  'typically': 895,
#  'Segal': 896,
#  'landmark': 897,
#  'touring': 898,
#  'Avery': 899,
#  'Konda': 900,
#  'North': 901,
#  'October': 902,
#  'traffic': 903,
#  'roll': 904,
#  'start-up': 905,
#  ';': 906,
#  'interaction': 907,
#  'defender': 908,
#  'recipients': 909,
#  'Pitch': 910,
#  '$85,000': 911,
#  'imagery': 912,
#  'songs': 913,
#  'wealthy': 914,
#  'conquer': 915,
#  'College': 916,
#  'depending': 917,
#  'Sirens': 918,
#  'boosted': 919,
#  'Crick': 920,
#  'storage': 921,
#  'Vel': 922,
#  'nearly': 923,
#  'truly': 924,
#  'Morning': 925,
#  'Historic': 926,
#  'Idaho': 927,
#  'Richmond': 928,
#  'Phantom': 929,
#  'About': 930,
#  'funded': 931,
#  'accept': 932,
#  'Wikipedia': 933,
#  'century': 934,
#  'retreated': 935,
#  '6PR': 936,
#  'Parking': 937,
#  'Squirrel': 938,
#  'favour': 939,
#  '5th': 940,
#  'Graduated': 941,
#  'polaritons': 942,
#  'Fuhrer': 943,
#  'Beijing': 944,
#  'Ottawa': 945,
#  'Yorkshire': 946,
#  'Miguel': 947,
#  'branch': 948,
#  'observations': 949,
#  'Liverpool': 950,
#  'Nordic': 951,
#  'carbon': 952,
#  'developer': 953,
#  'argue': 954,
#  'civil': 955,
#  'hometown': 956,
#  'Abdee': 957,
#  '1938': 958,
#  'chorus': 959,
#  'vision': 960,
#  'display': 961,
#  'Nunez': 962,
#  'becoming': 963,
#  'transformed': 964,
#  'landslide': 965,
#  'focus': 966,
#  '5,000': 967,
#  'animals': 968,
#  'faced': 969,
#  'capitalisation': 970,
#  'professional': 971,
#  'stick': 972,
#  'Teater': 973,
#  'Live': 974,
#  'taken': 975,
#  'lumped': 976,
#  'Gloomy': 977,
#  'Chief': 978,
#  'Saskatchewan': 979,
#  'Jew': 980,
#  'visiting': 981,
#  'redshirt': 982,
#  '0': 983,
#  'paleontologist': 984,
#  'fireman': 985,
#  'attached': 986,
#  'judge': 987,
#  'Albigenses': 988,
#  'Fairfax': 989,
#  'vocal': 990,
#  'including': 991,
#  'tell': 992,
#  'portable': 993,
#  'actually': 994,
#  'accessories': 995,
#  'Harlan': 996,
#  '1959': 997,
#  'Delta': 998,
#  'tobacco': 999,
#  'Phoenix': 1000,
#  ...}

# %%
words
# Out:
# {'48',
#  'artist',
#  'stops',
#  'Parish',
#  'pulling',
#  'Anti-Jacksonian',
#  'invasion',
#  'carrying',
#  'verdicts',
#  'András',
#  '1974',
#  'devise',
#  'Mendelssohn',
#  'Scouting',
#  'Coleman',
#  'Houston',
#  'Roberta',
#  'preliminary',
#  'Bambos',
#  'fills',
#  'resident',
#  'Indie',
#  'meandering',
#  'realists',
#  'Also',
#  'USSR',
#  'room',
#  'Twin',
#  'college',
#  'colonial',
#  'stringer',
#  'Landes',
#  'Goan',
#  'phrase',
#  'Greece',
#  'Pro',
#  'Bobby',
#  'Germans',
#  '16,000',
#  'OASA',
#  'ISAP',
#  'attract',
#  'visited',
#  'Oahu',
#  'goaltender',
#  'der',
#  'a',
#  'naval',
#  'Orchestra',
#  'exploded',
#  'bandmates',
#  'drafted',
#  'USA',
#  'planted',
#  'won',
#  'depots',
#  'guard',
#  'Mostar',
#  'Mistress',
#  'Italian-American',
#  'heard',
#  'sandbox',
#  'Poolesville',
#  'BP',
#  '50',
#  'Salling',
#  'J',
#  'Frazier',
#  'muscles',
#  'spelt',
#  'Sankranthi',
#  'Bontnewydd',
#  'Tampa',
#  'faculty',
#  'banjo-guitars',
#  'fought',
#  'cooperation',
#  'sleeve',
#  'project',
#  'Copeland',
#  'Mongolia',
#  'Zealand',
#  'polytechnic',
#  'seven',
#  'launching',
#  '1988',
#  'Civic',
#  'father',
#  'twists',
#  'Buddhist',
#  'testified',
#  'Szomorú',
#  'Origins',
#  'nail',
#  'crafting',
#  'refuse',
#  'Information',
#  'tenth',
#  'Jacksonville',
#  'preserve',
#  'Version',
#  'Sacramento',
#  'post-Ceauşescu',
#  'Vasárnap',
#  'features',
#  'bodybuilding',
#  'Marcus',
#  'notable',
#  'Civil',
#  "J'ai",
#  'Armistice',
#  'designated',
#  'Timberlands',
#  'Orleans',
#  'contractions',
#  'explanation',
#  'Resistance',
#  'soldiers',
#  'brother',
#  'Many',
#  'tirailleurs',
#  'Tuesdays',
#  'Gives',
#  'newly',
#  'Luigi',
#  'Gascony',
#  'puny',
#  'north',
#  'Sayler',
#  'county',
#  'turn',
#  'Olympics',
#  'probable',
#  'Salem',
#  'Newcomer',
#  'Vendorado',
#  '16-year-old',
#  'DNA',
#  'loans',
#  'stop',
#  'ILPAP',
#  'Junction',
#  'kick-starting',
#  'Buchanan',
#  'conditions',
#  'men',
#  'citizens',
#  'board',
#  'Baltimore',
#  'aim',
#  'Christi',
#  'their',
#  'Loft',
#  'lush',
#  'Philippines',
#  'Hawker',
#  'decideed',
#  'making',
#  '1-2',
#  'Flanders',
#  'undisturbed',
#  'pillboxes',
#  'Frank',
#  'shoppers',
#  'Glastonbury',
#  'Saco',
#  'sophomores',
#  'course',
#  'implicate',
#  'kindergartens',
#  'NYC',
#  '1937',
#  'Holdsworth',
#  '1960s',
#  'inscriptions',
#  'citizenship',
#  'Australia',
#  'Skating',
#  'vacated',
#  'gather',
#  'commune',
#  'allotted',
#  'French',
#  'Rob',
#  'CSHL',
#  'referring',
#  'Surabaya',
#  'believe',
#  '2.0',
#  'Angelo',
#  'destruction',
#  'reading',
#  'firm',
#  'ranged',
#  'transferred',
#  'Engineer',
#  'war',
#  'Aufklarung',
#  'revolutionary',
#  'Rice',
#  'box',
#  'dissertation',
#  'tragic',
#  'turns',
#  'Brazil',
#  'relocation',
#  'sings',
#  'standings',
#  'Brazilian',
#  'just',
#  'spelled',
#  'Carvolth',
#  'wrecked',
#  'Winkel',
#  'Sydney',
#  'Results',
#  'immobilise',
#  'reach',
#  'Tyne',
#  'affair',
#  'two',
#  'pencils',
#  'bridges',
#  'homebuilder',
#  'republicanism',
#  'specialist',
#  'fluent',
#  'Manwatch',
#  'Gutawa',
#  'give',
#  'offers',
#  'dozen',
#  'pauperes',
#  '30',
#  '?',
#  'Peninsula',
#  'Park',
#  'sound',
#  'fury',
#  'injuring',
#  '2007',
#  'Lady',
#  'author',
#  'All-SWC',
#  'BED',
#  'Professor',
#  'rooted',
#  'control',
#  'Market',
#  'Adan',
#  '$35,000',
#  'milking',
#  'amongst',
#  'Next',
#  'Air',
#  'tenor',
#  'Li',
#  'games',
#  'Spanish-Ilocano',
#  'presenting',
#  'Turpentine',
#  'condition',
#  'traveled',
#  'separate',
#  'midfielder',
#  'trying',
#  'savings',
#  'Squirrell',
#  'AM',
#  'Contest',
#  'Iowa',
#  'Evolution',
#  'Bowl',
#  '1960',
#  '34',
#  'due',
#  'technique',
#  'WTCC',
#  'key',
#  'wood',
#  'behalf',
#  'maximize',
#  'cortex',
#  'severely',
#  'Lucy',
#  'casting',
#  'Adeon',
#  'AMEL',
#  'Independence',
#  'Paulo',
#  'UPI',
#  'Science',
#  'association',
#  'BayCon',
#  'Surfwear',
#  'Legacy',
#  'off',
#  'Mattias',
#  'NAACP',
#  'Super',
#  'pro-life',
#  'deer',
#  'renumbered',
#  'followed',
#  'Representative',
#  'Toshiba-EMI',
#  'moments',
#  'come',
#  'millions',
#  'extensively',
#  'Pump',
#  'intervention',
#  'Buffalo',
#  '-1985',
#  'A.',
#  'announced',
#  'Digilogue',
#  'carbonate',
#  'facility',
#  'Marlboro',
#  'bearing',
#  'Camp',
#  'Shree',
#  'Newark',
#  'anniversary',
#  'interstate',
#  'India',
#  'Miličević',
#  'underwent',
#  'Lee',
#  'Nassau',
#  'crops',
#  'tributes',
#  'Menestrallus',
#  'poems',
#  'ca',
#  'belt',
#  '15%',
#  'Laser',
#  'controller',
#  'Vision',
#  'Was',
#  'attitude',
#  'subjects',
#  'Nâdiy',
#  'Antipodes',
#  'Activities',
#  'Fiji',
#  'journal',
#  'oldest',
#  'tours',
#  '1980',
#  'Oh',
#  'Fremantle',
#  'Saturnino',
#  'Cuba',
#  'Vertical',
#  '1830',
#  'street',
#  'server',
#  'destiny',
#  '1837-1927',
#  'Place',
#  'schools',
#  'How',
#  'upcoming',
#  'defence',
#  'Lieutenant',
#  'Nicola',
#  'Mel',
#  'approachable',
#  'outrage',
#  'filled',
#  'life-threatening',
#  'Travel',
#  'Sudan',
#  'Esteban',
#  'future',
#  '2006/07',
#  'Maratha',
#  'hillock',
#  'Safety',
#  'tournament',
#  '2,700,000',
#  'Twenty-fourth',
#  'pass',
#  'research',
#  'commentary',
#  'Irene',
#  'gaily',
#  'Darrell',
#  'Esther',
#  'MVP',
#  'rebellion',
#  'natives',
#  'enginehouse',
#  'OSC-DIS',
#  'Raven',
#  'real',
#  'rookie',
#  'name',
#  'structure',
#  'Christianos',
#  'occupations',
#  'Athens',
#  'Columbia',
#  'District',
#  'Vancouver',
#  'neck',
#  'period',
#  'Java',
#  'Canadian',
#  'Modeling',
#  'traded',
#  'Bains',
#  'responded',
#  'Mad',
#  'Second',
#  'obvious',
#  'subdue',
#  'reformed',
#  'get',
#  'Space',
#  'polemicist',
#  'headquarters',
#  'feud',
#  'Organization',
#  '98th',
#  'Cambridge',
#  'affairs',
#  'briefly',
#  "Miller's",
#  'Acting',
#  'Bennett',
#  'detail',
#  'altogether',
#  'owns',
#  'Sentinel',
#  'Bov',
#  'Labor',
#  'dirty',
#  'KGB',
#  'damage',
#  'traveling',
#  'Brandhorst',
#  'damaged',
#  'determined',
#  'present',
#  'Newell',
#  '7-inning',
#  'XVI',
#  'jacks',
#  '17',
#  'learning',
#  'Wachter',
#  'scoreless',
#  'Swedish',
#  'choose',
#  'Realists',
#  'popularly',
#  '45',
#  'Graeme',
#  'named',
#  'M.',
#  'Holmes',
#  'Problem',
#  'Harry',
#  'drop',
#  '7.2',
#  'collegiate',
#  'laureate',
#  'commitments',
#  'Rex',
#  'little',
#  'directed',
#  'Universe',
#  'Divizia',
#  '200000',
#  'masters',
#  'Scribner',
#  '5:40',
#  'participants',
#  'programs',
#  'Studies',
#  'succeeded',
#  'dominance',
#  'north-west',
#  'Garrigan',
#  'fifteen',
#  'cartridges',
#  'four-year',
#  'ruthlessly',
#  'Baggage',
#  'Cosham',
#  'plans',
#  'accepting',
#  'Riding',
#  'Fortification',
#  'firmly',
#  'philosopher',
#  'Brixton',
#  'Rahel',
#  'quitting',
#  'local',
#  'László',
#  'Brensbach',
#  'merged',
#  'tall',
#  'media-created',
#  '38',
#  'church',
#  'vice',
#  'Adelson',
#  'Phillip',
#  'resides',
#  'And',
#  'analogue',
#  'area',
#  'Alfred',
#  'Deser',
#  'helps',
#  'families',
#  '1969',
#  'pick',
#  'listening',
#  '300',
#  'seemed',
#  'Department',
#  'Pedr',
#  'channel',
#  'bankruptcy',
#  'Vijaynagar',
#  'solo',
#  'Patrol',
#  'driver',
#  'Pezuela',
#  'Telemundo',
#  'siren',
#  'Tomo',
#  'Šibenik-Knin',
#  'concern',
#  'assistance',
#  'power',
#  'performance',
#  'are',
#  'colorfully',
#  'mid-range',
#  'Kuala',
#  'Moderni',
#  'youngest',
#  'gain',
#  'Seven',
#  'commonly',
#  'vein',
#  'Stoloff',
#  '883Jia',
#  'contenders',
#  'brand',
#  'pulled',
#  'Intelligence',
#  'reshaped',
#  'hotels',
#  'numerous',
#  'band',
#  'recruit',
#  'wins',
#  'X86-based',
#  'Adenes',
#  'elegant',
#  'among',
#  'Osc-Dis',
#  'hands',
#  'starter',
#  'Markets',
#  'Speaker',
#  'competition',
#  'sanctity',
#  'Tram',
#  'anti-aircraft',
#  'Challenge',
#  'led',
#  'presence',
#  'organs',
#  'Colclough',
#  'guru',
#  'double',
#  'Record',
#  'MySpace',
#  'Have',
#  'Mount',
#  'retreat',
#  '1,000,000',
#  'below',
#  'count',
#  'signifies',
#  'Cascade',
#  'silence',
#  'Pie',
#  'Faludi',
#  'BIRT',
#  'between',
#  '1847',
#  'G.',
#  'maintained',
#  'Italian',
#  'Daniels',
#  'metal',
#  'showed',
#  'RPO',
#  'links',
#  'modified',
#  'backup',
#  'Bobick',
#  'starring',
#  'breaks',
#  'Per',
#  'Hendrix',
#  'since',
#  'Influence',
#  'wooden',
#  'daily',
#  'Orders',
#  'Attiko',
#  'Stewart',
#  'Ribandar',
#  'environment',
#  'rated',
#  'fact',
#  'spring',
#  'flash',
#  'Randall',
#  'environmentally',
#  'noon',
#  'AA',
#  'Barbara',
#  'administered',
#  'yrs',
#  'Le',
#  'surreal',
#  'players',
#  'Serbian',
#  'ranks',
#  'stock',
#  'Tilst',
#  'Established',
#  'Caernarfon',
#  'Laboratory',
#  'also',
#  'its',
#  'Scientific',
#  'far',
#  'article',
#  'Image',
#  'Minnich',
#  'considered',
#  'beautiful',
#  'interface',
#  'partition',
#  'Records',
#  'excursionists',
#  'Prize',
#  'Corporations',
#  'picture',
#  'Pty',
#  'Updates',
#  'MAAA',
#  'Champdor',
#  'fun',
#  'self-contained',
#  'exclusively',
#  'Brodian',
#  'reference',
#  'fares',
#  'Sitamma',
#  'agent',
#  '93d',
#  'telegraphed',
#  'Beauty',
#  'Shadow',
#  'Championships',
#  'parallel',
#  'flank',
#  'leave',
#  'Poet',
#  'medal',
#  'recurred',
#  ':',
#  'tower',
#  'Quantitative',
#  'physically',
#  'muscular',
#  'portuguese',
#  'operation',
#  'humiliating',
#  'preoccupied',
#  '1843',
#  'residents',
#  'chaired',
#  'discovered',
#  'debut',
#  '16.4',
#  'Toronto',
#  'Minoru',
#  'Billiges',
#  'Count',
#  'Written',
#  'trumpeter',
#  '29',
#  'Bouncing',
#  'Liberties',
#  '1762',
#  'Diefenthal',
#  'crossing',
#  'Riperton',
#  'enter',
#  'stationery',
#  'Nakhonphink',
#  'Urbana-Champaign',
#  'too',
#  'Carlo',
#  'depths',
#  'threat',
#  '1993',
#  'Enrollment',
#  'Linkin',
#  'decided',
#  'hunters',
#  'transition',
#  'Complex',
#  'Frankfurt',
#  'Player',
#  'etc.',
#  'ride',
#  'owners',
#  'Capelli',
#  'industrial',
#  'fate',
#  'earliest',
#  'America',
#  'did',
#  'footage',
#  'buffalo',
#  'AGS',
#  'Oakland',
#  'eligible',
#  'Bunzel',
#  'serious',
#  '1895',
#  'Ask.com',
#  'Lubbock',
#  'Metrobus',
#  'fulfill',
#  'hoped',
#  'By',
#  'Pavilion',
#  'skulls',
#  'programme',
#  '1819',
#  'children',
#  'inexplicable',
#  'constructed',
#  'weapon',
#  'Falls',
#  'note',
#  'Wiscasset',
#  '144',
#  'Philip',
#  'architect',
#  'Auton',
#  'part-time',
#  'Eagles',
#  'boiling',
#  'Elders',
#  'cool',
#  'Mesa',
#  'National',
#  'McGill',
#  'summer',
#  'hit',
#  'Maxfield',
#  'zoviet*france',
#  'Moses',
#  'replaced',
#  'Gostkócity',
#  'functionaries',
#  'Dark',
#  'element',
#  'avoid',
#  'legislative',
#  'child',
#  'principles',
#  '1839',
#  'prastut',
#  'devices',
#  'rain',
#  'collapsible',
#  'Experimental',
#  'sensitivity',
#  'Schelling',
#  'shut',
#  'ka',
#  'Vaz',
#  'battery',
#  'switch',
#  'Sheridan',
#  'Joseph',
#  'experiments',
#  'feet',
#  'things',
#  'probability',
#  'Bruins',
#  'totaling',
#  'York',
#  'Houser',
#  'Leto',
#  'regarded',
#  'camp',
#  'trial',
#  '/',
#  'Former',
#  'Widner',
#  'names',
#  'Iceland',
#  'furthest',
#  'Schlegel',
#  "'",
#  'invade',
#  'Outback',
#  'gathered',
#  'villain',
#  'promote',
#  'jackpot',
#  'month-long',
#  'packed',
#  'Shore',
#  'Baby',
#  'villas',
#  'directing',
#  'Discovery',
#  '10:45',
#  'discerned',
#  'Gonzalo',
#  'rematch',
#  'model',
#  'Alexandria',
#  'Theatre',
#  'Brain',
#  'Weippert',
#  'government',
#  '1957',
#  'immediately',
#  'distribution',
#  '1973',
#  'nutrition',
#  'Bresh',
#  'inch',
#  'science',
#  '215',
#  'Farmington',
#  'promotion',
#  'Upon',
#  'technology',
#  'Hopkins',
#  'Shark',
#  'failings',
#  'W.',
#  'ads',
#  'Gustav',
#  'Bridgton',
#  'remembered',
#  'Fighting',
#  'top-10',
#  'outcome',
#  'branches',
#  '£500',
#  'displays',
#  'talents',
#  '$175',
#  'Varela',
#  'Nap',
#  'player',
#  'Baranja',
#  'spot-in',
#  'Defense',
#  'Ax2',
#  'untimely',
#  'serial',
#  'store',
#  'nineties',
#  'Rich',
#  'policy',
#  'omnibuses',
#  'Prior',
#  'classical',
#  'typically',
#  'Segal',
#  'landmark',
#  'touring',
#  'Avery',
#  'Konda',
#  'North',
#  'October',
#  'traffic',
#  'roll',
#  'start-up',
#  ';',
#  'interaction',
#  'defender',
#  'recipients',
#  'Pitch',
#  '$85,000',
#  'imagery',
#  'songs',
#  'wealthy',
#  'conquer',
#  'College',
#  'depending',
#  'Sirens',
#  'boosted',
#  'Crick',
#  'storage',
#  'Vel',
#  'nearly',
#  'truly',
#  'Morning',
#  'Historic',
#  'Idaho',
#  'Richmond',
#  'Phantom',
#  'About',
#  'funded',
#  'accept',
#  'Wikipedia',
#  'century',
#  'retreated',
#  '6PR',
#  'Parking',
#  'Squirrel',
#  'favour',
#  '5th',
#  'Graduated',
#  'polaritons',
#  'Fuhrer',
#  'Beijing',
#  'Ottawa',
#  'Yorkshire',
#  'Miguel',
#  'branch',
#  'observations',
#  'Liverpool',
#  'Nordic',
#  'carbon',
#  'developer',
#  'argue',
#  'civil',
#  'hometown',
#  'Abdee',
#  '1938',
#  'chorus',
#  'vision',
#  'display',
#  'Nunez',
#  'becoming',
#  'transformed',
#  'landslide',
#  'focus',
#  '5,000',
#  'animals',
#  'faced',
#  'capitalisation',
#  'professional',
#  'stick',
#  'Teater',
#  'Live',
#  'taken',
#  'lumped',
#  'Gloomy',
#  'Chief',
#  'Saskatchewan',
#  'Jew',
#  'visiting',
#  'redshirt',
#  '0',
#  'paleontologist',
#  'fireman',
#  'attached',
#  'judge',
#  'Albigenses',
#  'Fairfax',
#  'vocal',
#  'including',
#  'tell',
#  'portable',
#  'actually',
#  'accessories',
#  'Harlan',
#  '1959',
#  'Delta',
#  'tobacco',
#  'Phoenix',
#  ...}
